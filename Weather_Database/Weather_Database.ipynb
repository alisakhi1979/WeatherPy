# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from scipy.stats import linregress
from citipy import citipy
import requests
from config import weather_api_key

# %%
# create 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats,lngs)

coordinates = list(lat_lngs)
coordinates [1:10]
# Out:
# [(23.007704351873173, 79.15334421186873),
#  (27.530508024148645, -7.946970042312927),
#  (-79.25987992002155, -77.44849518257402),
#  (59.82799692759937, -16.470171777370027),
#  (89.09516668922473, -23.381133826929954),
#  (-63.66630741902208, -89.75106868990663),
#  (46.64570709981126, 5.956388969003399),
#  (60.37773409263002, 73.76005641501291),
#  (-24.889710088165288, -85.10106344964552)]

# %%
# Get the nearest city 
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 755

# %%
city_test = cities[1:100]
city_test
# Out:
# ['narsimhapur',
#  'tiznit',
#  'hofn',
#  'illoqqortoormiut',
#  'punta arenas',
#  'champagnole',
#  'surgut',
#  'marcona',
#  'coihaique',
#  'cayenne',
#  'la fleche',
#  'saldanha',
#  'port alfred',
#  'bambous virieux',
#  'port elizabeth',
#  'east london',
#  'muros',
#  'catamarca',
#  'kankavli',
#  'hermanus',
#  'arraial do cabo',
#  'qaanaaq',
#  'molteno',
#  'rocha',
#  'leh',
#  'chuy',
#  'hit',
#  'luderitz',
#  'prieska',
#  'ilulissat',
#  'guarapari',
#  'nadym',
#  'vardo',
#  'aksu',
#  'busselton',
#  'bandarbeyla',
#  'taolanaro',
#  'cap malheureux',
#  'monastyrshchina',
#  'balezino',
#  'jamestown',
#  'tokonou',
#  'beloha',
#  'tasiilaq',
#  'idenao',
#  'husavik',
#  'boende',
#  'attawapiskat',
#  'mutsamudu',
#  'ajdabiya',
#  'upernavik',
#  'sisimiut',
#  'bengkulu',
#  'ambatofinandrahana',
#  'kocevje',
#  'ancud',
#  'ozgon',
#  'ikere',
#  'barentsburg',
#  'sovetskiy',
#  'dalbandin',
#  'cururupu',
#  'abu dhabi',
#  'pastavy',
#  'lebu',
#  'pangnirtung',
#  'benavente',
#  'bathsheba',
#  'grand river south east',
#  'kavaratti',
#  'adrar',
#  'saryshagan',
#  'saint-pierre',
#  'shieli',
#  'dikson',
#  'tall kayf',
#  'cape town',
#  'touros',
#  'gilgit',
#  'paita',
#  'mahebourg',
#  'mar del plata',
#  'ostrovnoy',
#  'georgetown',
#  'axim',
#  'sinfra',
#  'thompson',
#  'sindand',
#  'san andres',
#  'saint-philippe',
#  'meulaboh',
#  'amderma',
#  'deh rawud',
#  'ardakan',
#  'praia',
#  'upington',
#  'jumla',
#  'kamskiye polyany',
#  'torbay']

# %%
# Exploring JSON Data 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
boston_url = url + "&q=" + "Boston"
boston_data = requests.get(boston_url).json()
boston_data
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 88.63,
#   'feels_like': 93.33,
#   'temp_min': 82.94,
#   'temp_max': 92.79,
#   'pressure': 1015,
#   'humidity': 53},
#  'visibility': 10000,
#  'wind': {'speed': 7, 'deg': 325, 'gust': 15.99},
#  'clouds': {'all': 90},
#  'dt': 1628361531,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1628329394,
#   'sunset': 1628380606},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# API call with OpenWeatherMap
# Url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
for index,city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_data.append ({"City": city.title(),
                           "Country" : city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc
                          }
                         )
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 50 of Set 7 | ushuaia
# Processing Record 51 of Set 7 | narsimhapur
# Processing Record 52 of Set 7 | tiznit
# Processing Record 53 of Set 7 | hofn
# Processing Record 54 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 55 of Set 7 | punta arenas
# Processing Record 56 of Set 7 | champagnole
# Processing Record 57 of Set 7 | surgut
# Processing Record 58 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 59 of Set 7 | coihaique
# Processing Record 60 of Set 7 | cayenne
# Processing Record 61 of Set 7 | la fleche
# Processing Record 62 of Set 7 | saldanha
# Processing Record 63 of Set 7 | port alfred
# Processing Record 64 of Set 7 | bambous virieux
# Processing Record 65 of Set 7 | port elizabeth
# Processing Record 66 of Set 7 | east london
# Processing Record 67 of Set 7 | muros
# Processing Record 68 of Set 7 | catamarca
# Processing Record 69 of Set 7 | kankavli
# City not found. Skipping...
# Processing Record 70 of Set 7 | hermanus
# Processing Record 71 of Set 7 | arraial do cabo
# Processing Record 72 of Set 7 | qaanaaq
# Processing Record 73 of Set 7 | molteno
# Processing Record 74 of Set 7 | rocha
# Processing Record 75 of Set 7 | leh
# Processing Record 76 of Set 7 | chuy
# Processing Record 77 of Set 7 | hit
# Processing Record 78 of Set 7 | luderitz
# Processing Record 79 of Set 7 | prieska
# Processing Record 80 of Set 7 | ilulissat
# Processing Record 81 of Set 7 | guarapari
# Processing Record 82 of Set 7 | nadym
# Processing Record 83 of Set 7 | vardo
# Processing Record 84 of Set 7 | aksu
# Processing Record 85 of Set 7 | busselton
# Processing Record 86 of Set 7 | bandarbeyla
# Processing Record 87 of Set 7 | taolanaro
# City not found. Skipping...
# Processing Record 88 of Set 7 | cap malheureux
# Processing Record 89 of Set 7 | monastyrshchina
# Processing Record 90 of Set 7 | balezino
# Processing Record 91 of Set 7 | jamestown
# Processing Record 92 of Set 7 | tokonou
# Processing Record 93 of Set 7 | beloha
# Processing Record 94 of Set 7 | tasiilaq
# Processing Record 95 of Set 7 | idenao
# Processing Record 96 of Set 7 | husavik
# Processing Record 97 of Set 7 | boende
# Processing Record 98 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 99 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 8 | ajdabiya
# Processing Record 2 of Set 8 | upernavik
# Processing Record 3 of Set 8 | sisimiut
# Processing Record 4 of Set 8 | bengkulu
# Processing Record 5 of Set 8 | ambatofinandrahana
# Processing Record 6 of Set 8 | kocevje
# Processing Record 7 of Set 8 | ancud
# Processing Record 8 of Set 8 | ozgon
# City not found. Skipping...
# Processing Record 9 of Set 8 | ikere
# Processing Record 10 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 8 | sovetskiy
# Processing Record 12 of Set 8 | dalbandin
# Processing Record 13 of Set 8 | cururupu
# Processing Record 14 of Set 8 | abu dhabi
# Processing Record 15 of Set 8 | pastavy
# Processing Record 16 of Set 8 | lebu
# Processing Record 17 of Set 8 | pangnirtung
# Processing Record 18 of Set 8 | benavente
# Processing Record 19 of Set 8 | bathsheba
# Processing Record 20 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 8 | kavaratti
# Processing Record 22 of Set 8 | adrar
# Processing Record 23 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 8 | saint-pierre
# Processing Record 25 of Set 8 | shieli
# Processing Record 26 of Set 8 | dikson
# Processing Record 27 of Set 8 | tall kayf
# Processing Record 28 of Set 8 | cape town
# Processing Record 29 of Set 8 | touros
# Processing Record 30 of Set 8 | gilgit
# Processing Record 31 of Set 8 | paita
# Processing Record 32 of Set 8 | mahebourg
# Processing Record 33 of Set 8 | mar del plata
# Processing Record 34 of Set 8 | ostrovnoy
# Processing Record 35 of Set 8 | georgetown
# Processing Record 36 of Set 8 | axim
# Processing Record 37 of Set 8 | sinfra
# Processing Record 38 of Set 8 | thompson
# Processing Record 39 of Set 8 | sindand
# City not found. Skipping...
# Processing Record 40 of Set 8 | san andres
# Processing Record 41 of Set 8 | saint-philippe
# Processing Record 42 of Set 8 | meulaboh
# Processing Record 43 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 8 | deh rawud
# City not found. Skipping...
# Processing Record 45 of Set 8 | ardakan
# Processing Record 46 of Set 8 | praia
# Processing Record 47 of Set 8 | upington
# Processing Record 48 of Set 8 | jumla
# Processing Record 49 of Set 8 | kamskiye polyany
# Processing Record 50 of Set 8 | torbay
# Processing Record 1 of Set 9 | takoradi
# Processing Record 2 of Set 9 | masallatah
# Processing Record 3 of Set 9 | sodertalje
# City not found. Skipping...
# Processing Record 4 of Set 9 | abha
# Processing Record 5 of Set 9 | iqaluit
# Processing Record 6 of Set 9 | bredasdorp
# Processing Record 7 of Set 9 | havoysund
# Processing Record 8 of Set 9 | santa marta
# Processing Record 9 of Set 9 | cockburn town
# Processing Record 10 of Set 9 | marawi
# Processing Record 11 of Set 9 | atbasar
# Processing Record 12 of Set 9 | fitchburg
# Processing Record 13 of Set 9 | ati
# Processing Record 14 of Set 9 | bereznik
# Processing Record 15 of Set 9 | valparaiso
# Processing Record 16 of Set 9 | aksarka
# Processing Record 17 of Set 9 | caravelas
# Processing Record 18 of Set 9 | ponta do sol
# Processing Record 19 of Set 9 | pemba
# Processing Record 20 of Set 9 | ribeira grande
# Processing Record 21 of Set 9 | zagare
# Processing Record 22 of Set 9 | tevriz
# Processing Record 23 of Set 9 | sinjar
# Processing Record 24 of Set 9 | oranjemund
# Processing Record 25 of Set 9 | najran
# Processing Record 26 of Set 9 | senanga
# Processing Record 27 of Set 9 | coquimbo
# Processing Record 28 of Set 9 | castro
# Processing Record 29 of Set 9 | limon
# Processing Record 30 of Set 9 | tereze
# Processing Record 31 of Set 9 | olinda
# Processing Record 32 of Set 9 | anloga
# Processing Record 33 of Set 9 | sept-iles
# Processing Record 34 of Set 9 | kolchugino
# Processing Record 35 of Set 9 | vila velha
# Processing Record 36 of Set 9 | saint-francois
# Processing Record 37 of Set 9 | san cristobal
# Processing Record 38 of Set 9 | san luis
# Processing Record 39 of Set 9 | fenoarivo
# Processing Record 40 of Set 9 | shubarshi
# Processing Record 41 of Set 9 | klaksvik
# Processing Record 42 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 9 | martil
# Processing Record 44 of Set 9 | saint-augustin
# Processing Record 45 of Set 9 | gollere
# City not found. Skipping...
# Processing Record 46 of Set 9 | pisco
# Processing Record 47 of Set 9 | kanniyakumari
# Processing Record 48 of Set 9 | saint-joseph
# Processing Record 49 of Set 9 | taoudenni
# Processing Record 50 of Set 9 | xique-xique
# Processing Record 1 of Set 10 | rayevskiy
# Processing Record 2 of Set 10 | marystown
# Processing Record 3 of Set 10 | hobyo
# Processing Record 4 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 10 | tabasalu
# Processing Record 6 of Set 10 | albanel
# Processing Record 7 of Set 10 | narsaq
# Processing Record 8 of Set 10 | kruisfontein
# Processing Record 9 of Set 10 | abu samrah
# Processing Record 10 of Set 10 | codrington
# Processing Record 11 of Set 10 | bubaque
# Processing Record 12 of Set 10 | sao geraldo do araguaia
# Processing Record 13 of Set 10 | oeiras
# Processing Record 14 of Set 10 | andenes
# Processing Record 15 of Set 10 | walvis bay
# Processing Record 16 of Set 10 | vila franca do campo
# Processing Record 17 of Set 10 | mormugao
# Processing Record 18 of Set 10 | lamu
# Processing Record 19 of Set 10 | vicuna
# Processing Record 20 of Set 10 | coria
# Processing Record 21 of Set 10 | beyneu
# Processing Record 22 of Set 10 | nouadhibou
# Processing Record 23 of Set 10 | matagami
# Processing Record 24 of Set 10 | ratnagiri
# Processing Record 25 of Set 10 | cidreira
# Processing Record 26 of Set 10 | wageningen
# Processing Record 27 of Set 10 | vieux-habitants
# Processing Record 28 of Set 10 | victoria
# Processing Record 29 of Set 10 | lieksa
# Processing Record 30 of Set 10 | iraucuba
# Processing Record 31 of Set 10 | matara
# Processing Record 32 of Set 10 | neuquen
# Processing Record 33 of Set 10 | gazli
# Processing Record 34 of Set 10 | ahvaz
# Processing Record 35 of Set 10 | lagoa
# Processing Record 36 of Set 10 | havre-saint-pierre
# Processing Record 37 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 38 of Set 10 | clyde river
# Processing Record 39 of Set 10 | capao da canoa
# Processing Record 40 of Set 10 | oriximina
# Processing Record 41 of Set 10 | maragogi
# Processing Record 42 of Set 10 | souillac
# Processing Record 43 of Set 10 | gijon
# Processing Record 44 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 45 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 10 | sambava
# Processing Record 47 of Set 10 | mogadishu
# Processing Record 48 of Set 10 | douentza
# Processing Record 49 of Set 10 | mehamn
# Processing Record 50 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 11 | guayaramerin
# Processing Record 2 of Set 11 | jalu
# Processing Record 3 of Set 11 | tazovskiy
# Processing Record 4 of Set 11 | caconda
# Processing Record 5 of Set 11 | sur
# Processing Record 6 of Set 11 | san rafael
# Processing Record 7 of Set 11 | yenagoa
# Processing Record 8 of Set 11 | tambura
# Processing Record 9 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 11 | dingle
# Processing Record 11 of Set 11 | geraldton
# Processing Record 12 of Set 11 | longyearbyen
# Processing Record 13 of Set 11 | nanortalik
# Processing Record 14 of Set 11 | campina verde
# Processing Record 15 of Set 11 | jadu
# Processing Record 16 of Set 11 | diego de almagro
# Processing Record 17 of Set 11 | carballo
# Processing Record 18 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 11 | keetmanshoop
# Processing Record 20 of Set 11 | la fria
# Processing Record 21 of Set 11 | serowe
# Processing Record 22 of Set 11 | mutoko
# Processing Record 23 of Set 11 | saint george
# Processing Record 24 of Set 11 | praia da vitoria
# Processing Record 25 of Set 11 | paamiut
# Processing Record 26 of Set 11 | karistos
# City not found. Skipping...
# Processing Record 27 of Set 11 | kashi
# Processing Record 28 of Set 11 | namibe
# Processing Record 29 of Set 11 | maceio
# Processing Record 30 of Set 11 | dossor
# Processing Record 31 of Set 11 | carutapera
# Processing Record 32 of Set 11 | ardee
# Processing Record 33 of Set 11 | salalah
# Processing Record 34 of Set 11 | charlottesville
# Processing Record 35 of Set 11 | marsa matruh
# Processing Record 36 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 11 | rakke
# Processing Record 38 of Set 11 | sorland
# Processing Record 39 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 11 | mwanza
# Processing Record 41 of Set 11 | kemin
# Processing Record 42 of Set 11 | lubango
# Processing Record 43 of Set 11 | korla
# Processing Record 44 of Set 11 | los llanos de aridane
# Processing Record 45 of Set 11 | zubtsov
# Processing Record 46 of Set 11 | bereda
# Processing Record 47 of Set 11 | melfi
# Processing Record 48 of Set 11 | kapuskasing
# Processing Record 49 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 50 of Set 11 | gidam
# Processing Record 1 of Set 12 | mayumba
# Processing Record 2 of Set 12 | san pedro
# Processing Record 3 of Set 12 | mweka
# Processing Record 4 of Set 12 | necochea
# Processing Record 5 of Set 12 | barcelos
# Processing Record 6 of Set 12 | brae
# Processing Record 7 of Set 12 | pedreiras
# Processing Record 8 of Set 12 | jurm
# Processing Record 9 of Set 12 | bonavista
# Processing Record 10 of Set 12 | mattru
# Processing Record 11 of Set 12 | herat
# Processing Record 12 of Set 12 | kazerun
# Processing Record 13 of Set 12 | menongue
# Processing Record 14 of Set 12 | ponta delgada
# Processing Record 15 of Set 12 | adre
# Processing Record 16 of Set 12 | jharsuguda
# Processing Record 17 of Set 12 | bahia blanca
# Processing Record 18 of Set 12 | horodnya
# Processing Record 19 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 12 | emba
# Processing Record 21 of Set 12 | lima
# Processing Record 22 of Set 12 | margate
# Processing Record 23 of Set 12 | gao
# Processing Record 24 of Set 12 | port hawkesbury
# Processing Record 25 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 26 of Set 12 | la romana
# Processing Record 27 of Set 12 | ribeira brava
# Processing Record 28 of Set 12 | sao joao da barra
# Processing Record 29 of Set 12 | san lorenzo
# Processing Record 30 of Set 12 | yining
# Processing Record 31 of Set 12 | baymak
# Processing Record 32 of Set 12 | ferrol
# Processing Record 33 of Set 12 | kismayo
# Processing Record 34 of Set 12 | sao felix do xingu
# Processing Record 35 of Set 12 | rundu
# Processing Record 36 of Set 12 | sokoni
# Processing Record 37 of Set 12 | gazojak
# Processing Record 38 of Set 12 | araouane
# Processing Record 39 of Set 12 | boa vista
# Processing Record 40 of Set 12 | santa fe
# Processing Record 41 of Set 12 | khakhea
# Processing Record 42 of Set 12 | belyy yar
# Processing Record 43 of Set 12 | livingstonia
# Processing Record 44 of Set 12 | carnarvon
# Processing Record 45 of Set 12 | rincon
# Processing Record 46 of Set 12 | janauba
# Processing Record 47 of Set 12 | elmadag
# Processing Record 48 of Set 12 | usinsk
# Processing Record 49 of Set 12 | vestmanna
# Processing Record 50 of Set 12 | jacobina
# Processing Record 1 of Set 13 | slobidka
# Processing Record 2 of Set 13 | harrisonburg
# Processing Record 3 of Set 13 | dutse
# Processing Record 4 of Set 13 | westport
# Processing Record 5 of Set 13 | doha
# Processing Record 6 of Set 13 | engerwitzdorf
# Processing Record 7 of Set 13 | oldenburg
# Processing Record 8 of Set 13 | riyadh
# Processing Record 9 of Set 13 | porto novo
# Processing Record 10 of Set 13 | lisala
# Processing Record 11 of Set 13 | hamilton
# Processing Record 12 of Set 13 | kerchevskiy
# Processing Record 13 of Set 13 | santa helena
# Processing Record 14 of Set 13 | silca
# Processing Record 15 of Set 13 | fishers
# Processing Record 16 of Set 13 | chapais
# Processing Record 17 of Set 13 | paraguacu paulista
# Processing Record 18 of Set 13 | cruz alta
# Processing Record 19 of Set 13 | rawson
# Processing Record 20 of Set 13 | elizabethtown
# Processing Record 21 of Set 13 | batsfjord
# Processing Record 22 of Set 13 | khorixas
# Processing Record 23 of Set 13 | sault sainte marie
# Processing Record 24 of Set 13 | marzuq
# Processing Record 25 of Set 13 | wattegama
# Processing Record 26 of Set 13 | raudeberg
# Processing Record 27 of Set 13 | el alto
# Processing Record 28 of Set 13 | ilhabela
# Processing Record 29 of Set 13 | berlevag
# Processing Record 30 of Set 13 | high rock
# Processing Record 31 of Set 13 | lahij
# Processing Record 32 of Set 13 | wadi maliz
# Processing Record 33 of Set 13 | tikamgarh
# Processing Record 34 of Set 13 | sao filipe
# Processing Record 35 of Set 13 | san ignacio
# Processing Record 36 of Set 13 | puerto narino
# Processing Record 37 of Set 13 | the valley
# Processing Record 38 of Set 13 | yar-sale
# Processing Record 39 of Set 13 | kincardine
# Processing Record 40 of Set 13 | jimeta
# Processing Record 41 of Set 13 | vestmannaeyjar
# Processing Record 42 of Set 13 | guaraniacu
# Processing Record 43 of Set 13 | basmat
# Processing Record 44 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 45 of Set 13 | ostersund
# Processing Record 46 of Set 13 | barreiras
# Processing Record 47 of Set 13 | saint-georges
# Processing Record 48 of Set 13 | karpogory
# Processing Record 49 of Set 13 | mutis
# Processing Record 50 of Set 13 | colina
# Processing Record 1 of Set 14 | borba
# Processing Record 2 of Set 14 | galich
# Processing Record 3 of Set 14 | camana
# Processing Record 4 of Set 14 | bad sooden-allendorf
# Processing Record 5 of Set 14 | port blair
# Processing Record 6 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 14 | mizdah
# Processing Record 8 of Set 14 | itarema
# Processing Record 9 of Set 14 | presidencia roque saenz pena
# Processing Record 10 of Set 14 | manjeshwar
# Processing Record 11 of Set 14 | clarence town
# Processing Record 12 of Set 14 | luanda
# Processing Record 13 of Set 14 | biala podlaska
# Processing Record 14 of Set 14 | lokosovo
# Processing Record 15 of Set 14 | boden
# Processing Record 16 of Set 14 | eydhafushi
# Processing Record 17 of Set 14 | malanje
# Processing Record 18 of Set 14 | harper
# Processing Record 19 of Set 14 | altay
# Processing Record 20 of Set 14 | prainha
# Processing Record 21 of Set 14 | bousso
# Processing Record 22 of Set 14 | muisne
# Processing Record 23 of Set 14 | rio branco
# Processing Record 24 of Set 14 | gambela
# Processing Record 25 of Set 14 | mindelo
# Processing Record 26 of Set 14 | nador
# Processing Record 27 of Set 14 | albany
# Processing Record 28 of Set 14 | malkara
# Processing Record 29 of Set 14 | muli
# Processing Record 30 of Set 14 | dujuma
# City not found. Skipping...
# Processing Record 31 of Set 14 | padang
# Processing Record 32 of Set 14 | uruzgan
# Processing Record 33 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 34 of Set 14 | olafsvik
# Processing Record 35 of Set 14 | maniitsoq
# Processing Record 36 of Set 14 | estancia
# Processing Record 37 of Set 14 | toamasina
# Processing Record 38 of Set 14 | mirina
# City not found. Skipping...
# Processing Record 39 of Set 14 | warrington
# Processing Record 40 of Set 14 | warri
# Processing Record 41 of Set 14 | mucurapo
# Processing Record 42 of Set 14 | semnan
# Processing Record 43 of Set 14 | port-gentil
# Processing Record 44 of Set 14 | bealanana
# Processing Record 45 of Set 14 | pudozh
# Processing Record 46 of Set 14 | iaciara
# Processing Record 47 of Set 14 | bom jesus
# Processing Record 48 of Set 14 | santa isabel do rio negro
# Processing Record 49 of Set 14 | gamba
# Processing Record 50 of Set 14 | grootfontein
# Processing Record 1 of Set 15 | laguna
# Processing Record 2 of Set 15 | fomeque
# Processing Record 3 of Set 15 | sassandra
# Processing Record 4 of Set 15 | vilcun
# Processing Record 5 of Set 15 | plettenberg bay
# Processing Record 6 of Set 15 | voghera
# Processing Record 7 of Set 15 | mwinilunga
# Processing Record 8 of Set 15 | ornskoldsvik
# Processing Record 9 of Set 15 | comodoro rivadavia
# Processing Record 10 of Set 15 | bertoua
# Processing Record 11 of Set 15 | raga
# Processing Record 12 of Set 15 | lundamo
# Processing Record 13 of Set 15 | lukovetskiy
# Processing Record 14 of Set 15 | roald
# Processing Record 15 of Set 15 | puri
# Processing Record 16 of Set 15 | kutum
# Processing Record 17 of Set 15 | idukki
# Processing Record 18 of Set 15 | tuskegee
# Processing Record 19 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 15 | ouro preto do oeste
# Processing Record 21 of Set 15 | banepa
# Processing Record 22 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 23 of Set 15 | oblivskaya
# Processing Record 24 of Set 15 | kulunda
# Processing Record 25 of Set 15 | villarrica
# Processing Record 26 of Set 15 | yithion
# City not found. Skipping...
# Processing Record 27 of Set 15 | belmonte
# Processing Record 28 of Set 15 | bonthe
# Processing Record 29 of Set 15 | tingi
# Processing Record 30 of Set 15 | charleston
# Processing Record 31 of Set 15 | hithadhoo
# Processing Record 32 of Set 15 | mitsamiouli
# Processing Record 33 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 15 | ladario
# Processing Record 35 of Set 15 | muriti
# Processing Record 36 of Set 15 | usogorsk
# Processing Record 37 of Set 15 | calvia
# Processing Record 38 of Set 15 | hetauda
# Processing Record 39 of Set 15 | kindu
# Processing Record 40 of Set 15 | novara
# Processing Record 41 of Set 15 | rio grande
# Processing Record 42 of Set 15 | mao
# Processing Record 43 of Set 15 | tres arroyos
# Processing Record 44 of Set 15 | ndele
# Processing Record 45 of Set 15 | tocopilla
# Processing Record 46 of Set 15 | bronnitsy
# Processing Record 47 of Set 15 | los algarrobos
# Processing Record 48 of Set 15 | albert town
# Processing Record 49 of Set 15 | novoagansk
# Processing Record 50 of Set 15 | hamptons at boca raton
# Processing Record 1 of Set 16 | camacha
# Processing Record 2 of Set 16 | spring
# Processing Record 3 of Set 16 | fundata
# Processing Record 4 of Set 16 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 16 | cozumel
# Processing Record 6 of Set 16 | ust-tsilma
# Processing Record 7 of Set 16 | puerto del rosario
# Processing Record 8 of Set 16 | margherita di savoia
# Processing Record 9 of Set 16 | tucurui
# Processing Record 10 of Set 16 | angoche
# Processing Record 11 of Set 16 | juba
# Processing Record 12 of Set 16 | barsovo
# Processing Record 13 of Set 16 | joao pinheiro
# Processing Record 14 of Set 16 | kodar
# Processing Record 15 of Set 16 | banyo
# Processing Record 16 of Set 16 | corner brook
# Processing Record 17 of Set 16 | brokopondo
# Processing Record 18 of Set 16 | phalaborwa
# Processing Record 19 of Set 16 | kannur
# Processing Record 20 of Set 16 | daudnagar
# Processing Record 21 of Set 16 | tessalit
# Processing Record 22 of Set 16 | tera
# Processing Record 23 of Set 16 | ugoofaaru
# Processing Record 24 of Set 16 | bako
# Processing Record 25 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 16 | coulihaut
# City not found. Skipping...
# Processing Record 27 of Set 16 | itaituba
# Processing Record 28 of Set 16 | seara
# Processing Record 29 of Set 16 | hambantota
# Processing Record 30 of Set 16 | belomorsk
# Processing Record 31 of Set 16 | bandundu
# Processing Record 32 of Set 16 | aasiaat
# Processing Record 33 of Set 16 | talcahuano
# Processing Record 34 of Set 16 | idil
# Processing Record 35 of Set 16 | santa cruz del sur
# Processing Record 36 of Set 16 | henties bay
# Processing Record 37 of Set 16 | havelock
# Processing Record 38 of Set 16 | zhanaozen
# Processing Record 39 of Set 16 | alpena
# Processing Record 40 of Set 16 | san carlos de bariloche
# Processing Record 41 of Set 16 | kosh-agach
# Processing Record 42 of Set 16 | oyem
# Processing Record 43 of Set 16 | martinsicuro
# Processing Record 44 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 16 | umm kaddadah
# Processing Record 46 of Set 16 | chokwe
# Processing Record 47 of Set 16 | general roca
# Processing Record 48 of Set 16 | jizan
# Processing Record 49 of Set 16 | porbandar
# Processing Record 50 of Set 16 | halmstad
# Processing Record 1 of Set 17 | tonekabon
# Processing Record 2 of Set 17 | letlhakane
# Processing Record 3 of Set 17 | ouesso
# Processing Record 4 of Set 17 | rovaniemi
# Processing Record 5 of Set 17 | buritis
# Processing Record 6 of Set 17 | cabedelo
# Processing Record 7 of Set 17 | vieques
# Processing Record 8 of Set 17 | aurillac
# Processing Record 9 of Set 17 | deder
# Processing Record 10 of Set 17 | dzilam gonzalez
# Processing Record 11 of Set 17 | channel-port aux basques
# Processing Record 12 of Set 17 | la serena
# Processing Record 13 of Set 17 | kayes
# Processing Record 14 of Set 17 | talagang
# Processing Record 15 of Set 17 | tucuma
# Processing Record 16 of Set 17 | itacarambi
# Processing Record 17 of Set 17 | bani
# Processing Record 18 of Set 17 | prado
# Processing Record 19 of Set 17 | kariba
# Processing Record 20 of Set 17 | tandil
# Processing Record 21 of Set 17 | vigrestad
# Processing Record 22 of Set 17 | zlutice
# Processing Record 23 of Set 17 | lujan
# Processing Record 24 of Set 17 | makokou
# Processing Record 25 of Set 17 | grindavik
# Processing Record 26 of Set 17 | lavumisa
# Processing Record 27 of Set 17 | faya
# Processing Record 28 of Set 17 | scarborough
# Processing Record 29 of Set 17 | ponnani
# Processing Record 30 of Set 17 | formoso do araguaia
# City not found. Skipping...
# Processing Record 31 of Set 17 | san jose
# Processing Record 32 of Set 17 | kalabo
# Processing Record 33 of Set 17 | zhezkazgan
# Processing Record 34 of Set 17 | totskoye
# Processing Record 35 of Set 17 | izhma
# Processing Record 36 of Set 17 | phalodi
# Processing Record 37 of Set 17 | pimenta bueno
# Processing Record 38 of Set 17 | qaqortoq
# Processing Record 39 of Set 17 | mount pleasant
# Processing Record 40 of Set 17 | goderich
# Processing Record 41 of Set 17 | glimboca
# Processing Record 42 of Set 17 | jaramana
# City not found. Skipping...
# Processing Record 43 of Set 17 | amot
# Processing Record 44 of Set 17 | gat
# Processing Record 45 of Set 17 | jacareacanga
# Processing Record 46 of Set 17 | kuopio
# Processing Record 47 of Set 17 | soyo
# Processing Record 48 of Set 17 | matay
# Processing Record 49 of Set 17 | arroyos y esteros
# Processing Record 50 of Set 17 | salinopolis
# Processing Record 1 of Set 18 | micheweni
# Processing Record 2 of Set 18 | santiago del estero
# Processing Record 3 of Set 18 | imbituba
# Processing Record 4 of Set 18 | mkushi
# Processing Record 5 of Set 18 | nantucket
# Processing Record 6 of Set 18 | igrim
# Processing Record 7 of Set 18 | teguldet
# Processing Record 8 of Set 18 | banda aceh
# Processing Record 9 of Set 18 | curanilahue
# Processing Record 10 of Set 18 | turbat
# Processing Record 11 of Set 18 | ler
# Processing Record 12 of Set 18 | washington
# Processing Record 13 of Set 18 | nkhata bay
# Processing Record 14 of Set 18 | kaka
# Processing Record 15 of Set 18 | chacabuco
# Processing Record 16 of Set 18 | kjollefjord
# Processing Record 17 of Set 18 | ayagoz
# Processing Record 18 of Set 18 | grand-lahou
# Processing Record 19 of Set 18 | obo
# Processing Record 20 of Set 18 | nivala
# Processing Record 21 of Set 18 | uray
# Processing Record 22 of Set 18 | jashpurnagar
# Processing Record 23 of Set 18 | krasnyy yar
# Processing Record 24 of Set 18 | longonjo
# Processing Record 25 of Set 18 | chicama
# Processing Record 26 of Set 18 | talara
# Processing Record 27 of Set 18 | viligili
# City not found. Skipping...
# Processing Record 28 of Set 18 | bud
# Processing Record 29 of Set 18 | zaozerne
# Processing Record 30 of Set 18 | fecamp
# Processing Record 31 of Set 18 | manta
# Processing Record 32 of Set 18 | la peca
# Processing Record 33 of Set 18 | raghogarh
# Processing Record 34 of Set 18 | santa maria
# Processing Record 35 of Set 18 | lumeje
# Processing Record 36 of Set 18 | londa
# Processing Record 37 of Set 18 | taltal
# Processing Record 38 of Set 18 | evreux
# Processing Record 39 of Set 18 | tarko-sale
# Processing Record 40 of Set 18 | tazmalt
# Processing Record 41 of Set 18 | tucupita
# Processing Record 42 of Set 18 | kokkola
# Processing Record 43 of Set 18 | grand gaube
# Processing Record 44 of Set 18 | maarianhamina
# Processing Record 45 of Set 18 | battle creek
# Processing Record 46 of Set 18 | novyy urengoy
# Processing Record 47 of Set 18 | baraboo
# Processing Record 48 of Set 18 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 18 | kuytun
# Processing Record 50 of Set 18 | severnyy
# Processing Record 1 of Set 19 | gilazi
# City not found. Skipping...
# Processing Record 2 of Set 19 | thinadhoo
# Processing Record 3 of Set 19 | pozo colorado
# Processing Record 4 of Set 19 | boddam
# Processing Record 5 of Set 19 | awbari
# Processing Record 6 of Set 19 | murwara
# Processing Record 7 of Set 19 | pampas
# Processing Record 8 of Set 19 | armacao dos buzios
# City not found. Skipping...
# Processing Record 9 of Set 19 | muhos
# Processing Record 10 of Set 19 | monitos
# Processing Record 11 of Set 19 | aksaray
# Processing Record 12 of Set 19 | qasigiannguit
# Processing Record 13 of Set 19 | nuuk
# Processing Record 14 of Set 19 | chabahar
# Processing Record 15 of Set 19 | jaciara
# Processing Record 16 of Set 19 | lasa
# Processing Record 17 of Set 19 | buraydah
# Processing Record 18 of Set 19 | sabha
# Processing Record 19 of Set 19 | ivanishchi
# Processing Record 20 of Set 19 | alta floresta
# Processing Record 21 of Set 19 | tanout
# Processing Record 22 of Set 19 | mirabad
# Processing Record 23 of Set 19 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 24 of Set 19 | kemijarvi
# Processing Record 25 of Set 19 | rio gallegos
# Processing Record 26 of Set 19 | boali
# Processing Record 27 of Set 19 | inderborskiy
# City not found. Skipping...
# Processing Record 28 of Set 19 | astakos
# Processing Record 29 of Set 19 | opatija
# Processing Record 30 of Set 19 | sena madureira
# Processing Record 31 of Set 19 | conakry
# Processing Record 32 of Set 19 | caucaia
# Processing Record 33 of Set 19 | ngorongoro
# Processing Record 34 of Set 19 | sainte-suzanne
# Processing Record 35 of Set 19 | krasnoselkup
# Processing Record 36 of Set 19 | bay roberts
# Processing Record 37 of Set 19 | giddalur
# Processing Record 38 of Set 19 | salym
# Processing Record 39 of Set 19 | plavsk
# Processing Record 40 of Set 19 | esfahan
# Processing Record 41 of Set 19 | ipora
# Processing Record 42 of Set 19 | pychas
# Processing Record 43 of Set 19 | dilla
# Processing Record 44 of Set 19 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 19 | peniche
# Processing Record 46 of Set 19 | nizhnevartovsk
# Processing Record 47 of Set 19 | qandala
# Processing Record 48 of Set 19 | karema
# Processing Record 49 of Set 19 | zhitikara
# City not found. Skipping...
# Processing Record 50 of Set 19 | bilma
# Processing Record 1 of Set 20 | nizwa
# Processing Record 2 of Set 20 | amudat
# Processing Record 3 of Set 20 | springfield
# Processing Record 4 of Set 20 | santa isabel
# Processing Record 5 of Set 20 | gubkinskiy
# Processing Record 6 of Set 20 | urbano santos
# Processing Record 7 of Set 20 | shihezi
# Processing Record 8 of Set 20 | colwyn bay
# Processing Record 9 of Set 20 | ipira
# Processing Record 10 of Set 20 | isabela
# Processing Record 11 of Set 20 | keti bandar
# Processing Record 12 of Set 20 | omboue
# Processing Record 13 of Set 20 | botwood
# Processing Record 14 of Set 20 | laukaa
# Processing Record 15 of Set 20 | hvammstangi
# City not found. Skipping...
# Processing Record 16 of Set 20 | shelburne
# Processing Record 17 of Set 20 | panama city
# Processing Record 18 of Set 20 | progreso
# Processing Record 19 of Set 20 | ginir
# Processing Record 20 of Set 20 | montecristo
# Processing Record 21 of Set 20 | abapo
# Processing Record 22 of Set 20 | brotas
# Processing Record 23 of Set 20 | ochakiv
# Processing Record 24 of Set 20 | saint anthony
# Processing Record 25 of Set 20 | maloshuyka
# City not found. Skipping...
# Processing Record 26 of Set 20 | orillia
# Processing Record 27 of Set 20 | reriutaba
# Processing Record 28 of Set 20 | mubi
# Processing Record 29 of Set 20 | sivas
# Processing Record 30 of Set 20 | ewo
# Processing Record 31 of Set 20 | warsaw
# Processing Record 32 of Set 20 | tricase
# Processing Record 33 of Set 20 | iquique
# Processing Record 34 of Set 20 | asfi
# Processing Record 35 of Set 20 | hrubieszow
# Processing Record 36 of Set 20 | kampene
# Processing Record 37 of Set 20 | sechura
# Processing Record 38 of Set 20 | cheuskiny
# City not found. Skipping...
# Processing Record 39 of Set 20 | svetlyy
# Processing Record 40 of Set 20 | sinnamary
# Processing Record 41 of Set 20 | cozmesti
# Processing Record 42 of Set 20 | shadrinsk
# Processing Record 43 of Set 20 | uyuni
# Processing Record 44 of Set 20 | kayerkan
# Processing Record 45 of Set 20 | marsh harbour
# Processing Record 46 of Set 20 | oistins
# Processing Record 47 of Set 20 | muyezerskiy
# Processing Record 48 of Set 20 | doka
# Processing Record 49 of Set 20 | talnakh
# Processing Record 50 of Set 20 | naujamiestis
# Processing Record 1 of Set 21 | coari
# Processing Record 2 of Set 21 | aplahoue
# Processing Record 3 of Set 21 | okitipupa
# Processing Record 4 of Set 21 | hornepayne
# Processing Record 5 of Set 21 | sao jose da coroa grande
# Processing Record 6 of Set 21 | ylojarvi
# Processing Record 7 of Set 21 | merrill
# Processing Record 8 of Set 21 | dhankuta
# Processing Record 9 of Set 21 | trelew
# Processing Record 10 of Set 21 | moose factory
# Processing Record 11 of Set 21 | severnoye
# Processing Record 12 of Set 21 | traiguen
# Processing Record 13 of Set 21 | alcacer do sal
# Processing Record 14 of Set 21 | mookane
# Processing Record 15 of Set 21 | chalus
# Processing Record 16 of Set 21 | eyl
# Processing Record 17 of Set 21 | dapaong
# Processing Record 18 of Set 21 | vredendal
# Processing Record 19 of Set 21 | piterka
# Processing Record 20 of Set 21 | manoel urbano
# Processing Record 21 of Set 21 | polovinnoye
# Processing Record 22 of Set 21 | nemencine
# Processing Record 23 of Set 21 | ayios matthaios
# City not found. Skipping...
# Processing Record 24 of Set 21 | angola
# Processing Record 25 of Set 21 | neustadt
# Processing Record 26 of Set 21 | cantagalo
# Processing Record 27 of Set 21 | apac
# Processing Record 28 of Set 21 | cerrito
# Processing Record 29 of Set 21 | blankenberge
# Processing Record 30 of Set 21 | cahir
# Processing Record 31 of Set 21 | caranavi
# Processing Record 32 of Set 21 | cap-aux-meules
# Processing Record 33 of Set 21 | verkhnyaya salda
# Processing Record 34 of Set 21 | oktyabrskoye
# Processing Record 35 of Set 21 | puerto carreno
# Processing Record 36 of Set 21 | candelaria
# Processing Record 37 of Set 21 | montepuez
# Processing Record 38 of Set 21 | isiolo
# Processing Record 39 of Set 21 | salima
# Processing Record 40 of Set 21 | sari
# Processing Record 41 of Set 21 | denia
# Processing Record 42 of Set 21 | tubmanburg
# Processing Record 43 of Set 21 | veraval
# Processing Record 44 of Set 21 | mococa
# Processing Record 45 of Set 21 | nijar
# Processing Record 46 of Set 21 | lages
# Processing Record 47 of Set 21 | west bay
# Processing Record 48 of Set 21 | moffat
# Processing Record 49 of Set 21 | santarem
# Processing Record 50 of Set 21 | linhares
# Processing Record 1 of Set 22 | gbarnga
# Processing Record 2 of Set 22 | uzyn
# Processing Record 3 of Set 22 | villa rica
# Processing Record 4 of Set 22 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 22 | matoury
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# data frame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0   Narsimhapur      IN  22.9500  79.2000     74.50        92          78
# 1        Tiznit      MA  29.5833  -9.5000     67.84        70           5
# 2          Hofn      IS  64.2539 -15.2082     56.21        83         100
# 3  Punta Arenas      CL -53.1500 -70.9167     37.51        81           0
# 4   Champagnole      FR  46.7445   5.9135     61.48        89         100
# 5        Surgut      RU  61.2500  73.4167     62.78       100          40
# 6     Coihaique      CL -45.5752 -72.0662     46.35        53          75
# 7       Cayenne      GF   4.9333 -52.3333     86.09        77          75
# 8     La Fleche      FR  47.6982  -0.0755     67.03        62          99
# 9      Saldanha      ZA -33.0117  17.9442     51.85        72         100
#
#    Wind Speed Current Description
# 0        3.53       broken clouds
# 1        7.29           clear sky
# 2        8.93     overcast clouds
# 3       23.02           clear sky
# 4        5.73     overcast clouds
# 5        6.71                 fog
# 6        4.61          light rain
# 7        5.99       broken clouds
# 8       17.11     overcast clouds
# 9        6.42     overcast clouds

# %%
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 784 entries, 0 to 783
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 784 non-null    object
#  1   Country              784 non-null    object
#  2   Lat                  784 non-null    float64
#  3   Lng                  784 non-null    float64
#  4   Max Temp             784 non-null    float64
#  5   Humidity             784 non-null    int64
#  6   Cloudiness           784 non-null    int64
#  7   Wind Speed           784 non-null    float64
#  8   Current Description  784 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 55.2+ KB

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
